# %% [markdown]
# # Question 2 - Analysis 3

# %%
import os
import glob
import json
path = os.getcwd()
path1= os.path.join(path,'Most Popular')
path_json = os.path.join(path1,'Most shared')
json_files = [j for j in os.listdir(path_json) if j.endswith('.json')]

# %%
import glob
import re
import datetime
import time
shares = {}
months = []
res = []
x = []
y = []
#import calender
files = "*.json"
for j in glob.glob(os.path.join(path_json,files)):
            loaded_file = json.loads(open(j).read())
            copyright = loaded_file['copyright']
            results = loaded_file['results']
            for files in results:
                total_shares = files['total_shares']
                published_date = files['published_date']
                post_date = datetime.datetime.strptime(published_date,'%Y-%m-%d')
                month = post_date.month
                #print(month)
                months.append(month)
                for dates in months:
                    if dates not in shares:
                        shares[dates] = 1
                    else:
                        shares[dates] += 1
#print(shares)
x = list(shares.keys())
y = list(shares.values())
print(x)
# for key in shares.items():
#     if key[0] == 2:
#         x = key[1]
#         print(x)
                #print(published_date)
                #post_date = datetime.datetime.strptime(published_date,'%Y-%m-%d')
                #print(post_date)
                #change_date = post_date.strftime('%Y %B %d')
                #m = post_date.month
                #m.strftime('%B')
                #print(change_date)
                #month.append(change_date)
                #print(month)
                #month = change_date.month
                #calender.month_name[d]
                #print(s)
# Out:
# [2, 3]

# %%
import matplotlib.pyplot as plt
from pylab import *
color = ['blue', 'green']
explode = [0,0]
labels = ['February','March']
plt.pie(y, explode=explode, labels=labels, colors=color,autopct = '%1.1f%%', shadow=True, startangle=140)
title('Most shares in 2017')
plt.show()

# %%
import os
import glob
import json
path_to_json = 'C:/Users/hp/Desktop/2nd Sem Northeastern University/Data Analysis Using Python/Midterm Assignment/Most Popular/Most viewed'
json_files = [j for j in os.listdir(path_to_json) if j.endswith('.json')]

# %%
import glob
import re
t_views = {}
v_months = []
a = []
b = []
files = "*.json"
for j in glob.glob(os.path.join(path_to_json,files)):
            loaded_file = json.loads(open(j).read())
            copyright = loaded_file['copyright']
            results = loaded_file['results']
            for files in results:
                views = files['views']
                published_date = files['published_date']
                post_date = datetime.datetime.strptime(published_date,'%Y-%m-%d')
                month = post_date.month
                #print(month)
                v_months.append(month)
                for dates in v_months:
                    if dates not in t_views:
                        t_views[dates] = 1
                    else:
                        t_views[dates] += 1
#print(t_views)
a = list(t_views.keys())
print(a)
b = list(t_views.values())
print(b)
# Out:
# [1, 2, 3]
# [20, 172, 18]

# %%
# import matplotlib.pyplot as plt
# plt.bar(range(len(shares)),shares.values(),align = 'center')
# plt.xticks(range(len(shares)), shares.keys())
# plt.show()

# %%
import matplotlib.pyplot as plt
from pylab import *
color = ['gold', 'yellowgreen', 'lightcoral']
explode = [0,0,0]
labels = ['January','February','March']
plt.pie(b, explode=explode, labels=labels, colors=color,autopct = '%1.1f%%' ,shadow=True, startangle=140)
title('Most Views in 2017')
plt.show()
